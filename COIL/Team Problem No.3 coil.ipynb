# %%
import sys
sys.path.append('include')
from EMPY_COIL import *
sys.path.append(r'..\..\x64\Release') 
from EMPY_Field import *

# %%
from ngsolve.webgui import Draw
from netgen.webgui import Draw as DrawGeo
import sys
sys.path.append('..\model')
from BathPlateModel import BathPlateModel
sys.path.append('..\COIL\include')
from Prob3Coil import Prob3Coil

curveOrder=1
feOrder=3
#Dirichlet=True
boxz=200e-3
#B0=1 #(Tesla)
boxx=200e-3
boxy=200e-3
model=BathPlateModel(holes=2,boxx=boxx, boxy=boxy, boxz=boxz, div_thick=1)
DrawGeo(model.GetGeometry())
mesh=model.GetMesh()
Draw(mesh)

coil=model.coil
#coil=Prob3Coil()
DrawGeo(coil.geo)
# Out:
# Bath Plate Model    holes: 2    Thickness: 0.00635
# boxx=  0.2  boxy=  0.2  boxz=  0.2
# div_thick=  1
# name: hole1   mass: 7.619999999999999e-06   center: (0.02, 3.21245e-20, 5.42769e-20)
# name: hole2   mass: 7.619999999999999e-06   center: (-0.02, 3.21245e-20, 5.42769e-20)
# name: to_side   mass: 1.3335000000000002e-05   center: (9.92493e-19, 0.0178571, -3.5064e-21)
# name: from_side   mass: 1.3335000000000002e-05   center: (0, -0.0178571, -2.87941e-20)
# name: air   mass: 9.542999999999996e-05   center: (0, 0, -2.80284e-19)
# name: reduced   mass: 0.033372981638291145   center: (-1.29696e-17, -1.45627e-17, 9.02153e-20)
# conductive_region: to_side|from_side
# Conductor boundary: conductorBND|interface|interface2
# {'conductor': 32780000.0, 'to_side': 32780000.0, 'from_side': 32780000.0, 'air': 0, 'reduced': 0, 'hole1': 0, 'hole2': 0, 'default': 0}
# ...

# %% [markdown]
# ![image.png](attachment:38d7295c-bb74-4788-9c3f-2a658e7c33a1.png)

# %%
B=Bfield(coil.field)
A=Afield(coil.field)
mip = mesh(0., 0., 0)
print(B(mip))
with TaskManager():
    Draw(B,mesh, order=3, min=0, max=0.01)
with TaskManager():
    Draw(A,mesh, order=3, min=0, max=0.0001)
# Out:
# (0.004624415479224396, -4.750026798253925e-36, 0.007680154039799225)
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…

# %% [markdown]
# (0.004624415479224396, -0.0, 0.007680154039799225)　at (0,0,0)
#
# B Field
# ![image.png](attachment:d04701f9-198b-41a4-ba03-00b4cff77090.png)
# ![image.png](attachment:6eb93f0c-93e5-4b3e-97d8-ae6b2a58b355.png)
#
# A Field
# ![image.png](attachment:ccf04d54-655f-4d7b-b266-1a7f0f2deb0e.png)
