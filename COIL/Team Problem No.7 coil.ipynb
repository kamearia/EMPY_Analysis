# %%
import sys
sys.path.append('..\COIL\include')
from Prob7Coil import Prob7Coil
sys.path.append(r'..\..\bin\Release') 
from EMPY_Field import *
from ngsolve import *
from netgen.occ import *
from ngsolve.webgui import Draw
from netgen.webgui import Draw as DrawGeo
import sys

coils=Prob7Coil()
model=Box((0,0,0),(294.e-3,294.e-3, 19.e-3))
hole=Box((18e-3,18e-3,0),(126.e-3,126.e-3, 19.e-3))
model=model-hole
#DrawGeo(coils.geo+model)
geo =OCCGeometry(coils.geo+model)
mesh=Mesh (geo.GenerateMesh(maxh=10e-3))
#Draw(mesh)

B=Bfield(coils.field)
with TaskManager():
    Draw(B, mesh, order=3, min=0, max=0.01)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…

# %% [markdown]
# ![image.png](attachment:76f1344a-3ca6-4c70-9a32-d11e41be5ad6.png)
